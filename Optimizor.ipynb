# %%
import os 
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#loading mnist
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

#define batch size
batch_size = 100
#count how many batch
n_batch = mnist.train.num_examples // batch_size

#define placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

#create NN(input:784 into:10)
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

#loss
# loss = tf.reduce_mean(tf.square(y-prediction))gu
loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
#gradientDescent
#train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
#train_step = tf.train.AdamOptimizer(1e-2).minimize(loss)
train_step = tf.train.AdadeltaOptimizer(0.4).minimize(loss)

#init
init = tf.global_variables_initializer()

#result maintain(return most possible number)
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))

#get accuracy(turn T/F to possible(0.25))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(50):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict= {x:batch_xs,y:batch_ys})
            
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter "+str(epoch)+",Testing Accuracy "+ str(acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.7937
# Iter 1,Testing Accuracy 0.8721
# Iter 2,Testing Accuracy 0.8852
# Iter 3,Testing Accuracy 0.8925
# Iter 4,Testing Accuracy 0.8972
# Iter 5,Testing Accuracy 0.9019
# Iter 6,Testing Accuracy 0.9043
# Iter 7,Testing Accuracy 0.9056
# Iter 8,Testing Accuracy 0.9069
# Iter 9,Testing Accuracy 0.9086
# Iter 10,Testing Accuracy 0.9091
# Iter 11,Testing Accuracy 0.9104
# Iter 12,Testing Accuracy 0.9112
# Iter 13,Testing Accuracy 0.9122
# Iter 14,Testing Accuracy 0.913
# Iter 15,Testing Accuracy 0.9138
# Iter 16,Testing Accuracy 0.914
# Iter 17,Testing Accuracy 0.9147
# Iter 18,Testing Accuracy 0.9159
# Iter 19,Testing Accuracy 0.9161
# Iter 20,Testing Accuracy 0.9165
# Iter 21,Testing Accuracy 0.9175
# Iter 22,Testing Accuracy 0.918
# ...

# %%
#optimizor: Adam(1e-2)
Iter 0,Testing Accuracy 0.9203
Iter 1,Testing Accuracy 0.9252
Iter 2,Testing Accuracy 0.9285
Iter 3,Testing Accuracy 0.93
Iter 4,Testing Accuracy 0.9285
Iter 5,Testing Accuracy 0.9219
Iter 6,Testing Accuracy 0.9272
Iter 7,Testing Accuracy 0.9305
Iter 8,Testing Accuracy 0.9313
Iter 9,Testing Accuracy 0.9297
Iter 10,Testing Accuracy 0.9308
Iter 11,Testing Accuracy 0.9291
Iter 12,Testing Accuracy 0.9273
Iter 13,Testing Accuracy 0.8768
Iter 14,Testing Accuracy 0.8761
Iter 15,Testing Accuracy 0.7731
Iter 16,Testing Accuracy 0.7716
Iter 17,Testing Accuracy 0.7733
Iter 18,Testing Accuracy 0.7709
Iter 19,Testing Accuracy 0.7726
Iter 20,Testing Accuracy 0.7735
Iter 21,Testing Accuracy 0.7712
Iter 22,Testing Accuracy 0.7723
Iter 23,Testing Accuracy 0.7715
Iter 24,Testing Accuracy 0.098
Iter 25,Testing Accuracy 0.098
Iter 26,Testing Accuracy 0.098
Iter 27,Testing Accuracy 0.098
Iter 28,Testing Accuracy 0.098
Iter 29,Testing Accuracy 0.098

# %%
#optimizor: Adadelta(0.4)
Iter 0,Testing Accuracy 0.7937
Iter 1,Testing Accuracy 0.8721
Iter 2,Testing Accuracy 0.8852
Iter 3,Testing Accuracy 0.8925
Iter 4,Testing Accuracy 0.8972
Iter 5,Testing Accuracy 0.9019
Iter 6,Testing Accuracy 0.9043
Iter 7,Testing Accuracy 0.9056
Iter 8,Testing Accuracy 0.9069
Iter 9,Testing Accuracy 0.9086
Iter 10,Testing Accuracy 0.9091
Iter 11,Testing Accuracy 0.9104
Iter 12,Testing Accuracy 0.9112
Iter 13,Testing Accuracy 0.9122
Iter 14,Testing Accuracy 0.913
Iter 15,Testing Accuracy 0.9138
Iter 16,Testing Accuracy 0.914
Iter 17,Testing Accuracy 0.9147
Iter 18,Testing Accuracy 0.9159
Iter 19,Testing Accuracy 0.9161
Iter 20,Testing Accuracy 0.9165
Iter 21,Testing Accuracy 0.9175
Iter 22,Testing Accuracy 0.918
Iter 23,Testing Accuracy 0.9181
Iter 24,Testing Accuracy 0.9192
Iter 25,Testing Accuracy 0.9187
Iter 26,Testing Accuracy 0.9194
Iter 27,Testing Accuracy 0.9195
Iter 28,Testing Accuracy 0.9198
Iter 29,Testing Accuracy 0.9207
Iter 30,Testing Accuracy 0.9214
Iter 31,Testing Accuracy 0.9205
Iter 32,Testing Accuracy 0.9213
Iter 33,Testing Accuracy 0.9216
Iter 34,Testing Accuracy 0.9216
Iter 35,Testing Accuracy 0.9218
Iter 36,Testing Accuracy 0.9224
Iter 37,Testing Accuracy 0.9211
Iter 38,Testing Accuracy 0.9221
Iter 39,Testing Accuracy 0.9231
Iter 40,Testing Accuracy 0.9231
Iter 41,Testing Accuracy 0.9227
Iter 42,Testing Accuracy 0.9232
Iter 43,Testing Accuracy 0.923
Iter 44,Testing Accuracy 0.9238
Iter 45,Testing Accuracy 0.924
Iter 46,Testing Accuracy 0.9244
Iter 47,Testing Accuracy 0.9243
Iter 48,Testing Accuracy 0.9241
Iter 49,Testing Accuracy 0.925
