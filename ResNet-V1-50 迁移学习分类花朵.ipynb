# %%
##数据预处理
# 这是一个花朵识别的demo，数据集包含了5种花朵，数据都是脏数据 需要预处理
# 这里用到的数据集:http://download.tensorflow.org/example_images/flower_photos.tgz
# 注意这个数据集处理需要大概16G+的内存 否则会出现MemError，这一问题可通过减少图片数量来解决

import glob
import os.path
import numpy as np
import tensorflow as tf
from tensorflow.python.platform import gfile

#定义输入文件夹和数据存储文件名
INPUT_DATA = '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos'
OUTPUT_FILE = '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_processed_data.npy'

#设定验证集和测试集的百分比
VALIDATION_PERCENTAGE = 10
TEST_PERCENTAGE = 10

def create_image_list(sess, testing_percentage, validation_percentage):

    #列出输入文件夹下的所有子文件夹，此时sub_dirs里面除了有子文件夹还有它自身，在第一个
    sub_dirs = [x[0] for x in os.walk(INPUT_DATA)]
    #设置一个bool值，指定第一次循环的时候跳过母文件夹
    is_root_dir = True
    #print(sub_dirs)

    #初始化数据矩阵
    training_images = []
    training_labels = []
    testing_images = []
    testing_labels = []
    validation_images = []
    validation_labels= []
    current_label = 0

    #分别处理每个子文件夹
    for sub_dir in sub_dirs:
        #跳过第一个值，即跳过母文件夹
        if is_root_dir:
            is_root_dir = False
            continue

        #获取子目录中的所有图片文件
        extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
        #用列表记录所有图片文件
        file_list = []
        #获取此子目录的名字比如daisy
        dir_name = os.path.basename(sub_dir)
        #对此子目录中所有图片后缀的文件
        for extension in extensions:
            #获取每种图片的所有正则表达式
            file_glob = os.path.join(INPUT_DATA, dir_name, '*.' + extension)
            print(file_glob)
            #将所有符合正则表达式的文件名加入文件列表
            file_list.extend(glob.glob(file_glob))
        print(file_list)
        #如果没有文件跳出循环
        if not file_list:
            continue
        #print("processing ", dir_name)

        i = 0
        #对于每张图片
        for file_name in file_list:
            i+=1
            #打开图片文件
            #print("process num : ",i,"   processing", file_name, file=f)
            image_raw_data = gfile.FastGFile(file_name,'rb').read()
            #解码
            image = tf.image.decode_jpeg(image_raw_data)
            #如果图片格式不是float32则转为float32
            if image.dtype != tf.float32:
                image = tf.image.convert_image_dtype(image, dtype=tf.float32)
            #将图片源数据转为299*299
            image = tf.image.resize_images(image, [300,300])
            #得到此图片的数据
            image_value = sess.run(image)
            print(np.shape(image_value))

            #生成一个100以内的数
            chance = np.random.randint(100)
            #按概率随机分到三个数据集中
            if chance < validation_percentage:
                validation_images.append(image_value)
                validation_labels.append(current_label)
            elif chance < (testing_percentage + validation_percentage):
                testing_images.append(image_value)
                testing_labels.append(current_label)
            else:
                training_images.append(image_value)
                training_labels.append(current_label)
            if i%100 == 0:
                print(i, "images processed.")
        #处理完此种品种就将标签+1
        current_label += 1

    #将训练数据和标签以同样的方式打乱
    state = np.random.get_state()
    np.random.shuffle(training_images)
    np.random.set_state(state)
    np.random.shuffle(training_labels)

    #返回所有数据
    return np.asarray([training_images, training_labels,
                       validation_images, validation_labels, testing_images, testing_labels])


def main():
    with tf.Session() as sess:
        processed_data = create_image_list(sess, TEST_PERCENTAGE, VALIDATION_PERCENTAGE)
        #将数据存到文件中
        np.save(OUTPUT_FILE, processed_data)

if __name__ == "__main__":
    main()
# Out:
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/*.jpg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/*.jpeg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/*.JPG
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/*.JPEG
# ['/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/410425647_4586667858.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3292654244_4a220ab96f_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3102535578_ec8c12a7b6_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4713531680_1110a2fa07_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/2976723295_b16ab04231.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5333437251_ce0aa6925d_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/2225411981_6638c3e988.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3873271620_1d9d314f01_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/488849503_63a290a8c2_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/410421672_563550467c.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/298670754_f25edda891.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4608559939_3487bf3b62_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3713368809_eba7fa2fbf_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5212885371_fe27c406a2_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5050969148_a0090f762a.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/2141413229_3f0425f972_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/1540738662_7b4152e344_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5497730366_44d758d8f5.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/145862135_ab710de93c_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3264570182_c7ded528ba_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/1469726748_f359f4a8c5.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/685724528_6cd5cbe203.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/1793211631_68c31a74dc.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/2863863372_605e29c03e_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3026375835_a20ecdd140_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4279989256_9a48c0d194_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/512694812_48ba9c0b49_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5398974188_799753449c.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/2059172936_032ffc12aa.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5234278003_d827fcd73b_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4279990882_031482f8b6_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5172171681_5934378f08.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/509239741_28e2cfe492_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3315973481_850d2253e9_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5231103167_a03280e9f6_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3751835302_d5a03f55e8_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4625089819_55c45a189c.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/5083072098_81587295d5.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4505921907_21c8002fde.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/4881402397_1c664af2f7_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/505517255_cfbb6f6394.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/2501297526_cbd66a3f7e_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/roses/3494252600_29f26e3ff0_n.jpg',  ...
# processing  roses
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# processing...
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/*.jpg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/*.jpeg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/*.JPG
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/*.JPEG
# ['/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9593034725_0062f0d24e_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/5795159787_ebb51a5e75.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14245834619_153624f836.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/5014137563_d03eb0ed75_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9180706736_092d43088c.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/7288989324_c25d9febbf.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9350942387_5b1d043c26_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/5714327423_50af0cffe9.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/5110105726_53eb7a93be_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/5981645737_29eceac291_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/8383753520_8391dd80ee_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9242705328_eee8402a8d.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9611923744_013b29e4da_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/4561871220_47f420ca59_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14507818175_05219b051c_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/10555826524_423eb8bf71_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/4496202781_1d8e776ff5_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/7630517248_98fb8bee1f_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14219214466_3ca6104eae_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14421389519_d5fd353eb4.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14600779226_7bbc288d40_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/6299498346_b9774b6500.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/7133935763_82b17c8e1b_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/7630520686_e3a61ac763.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/12585131704_0f64b17059_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14551098743_2842e7a004_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/7410356270_9dff4d0e2e_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/4861391074_c3e122dab0_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9286947622_4822f4fc21.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/8619103877_d8c82c5f34_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14402451388_56545a374a_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14698531521_0c2f0c6539.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/10841136265_af473efc60.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/6148728633_27afc47b0c_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/8616684075_71923bb771_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9595857626_979c45e5bf_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/4757448834_a29a9538c9_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/11023214096_b5b39fab08.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/14073784469_ffb12f3387_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/10555749515_13a12a026e.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/7629784968_b953501902_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/5058708968_8bdcd29e63_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/daisy/9 ...
# processing  daisy
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# processing...
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/*.jpg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/*.jpeg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/*.JPG
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/*.JPEG
# ['/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/130685040_3c2fcec63e_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/164578909_51f245d3fa_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3990746027_338ee436d2_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4679869990_7c5f28f2fe_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3991423020_9aaf2b5974_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/405035580_94b793e71d.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3150964108_24dbec4b23_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3523398585_376960a611_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/110147301_ad921e2828.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3626132563_d955973447_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/100930342_92e8746431_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3498663243_42b39b4185_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/2322670828_34115a7050.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4561670472_0451888e32_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/2333321040_3960b9d67e_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/483880052_19fdb26a9f.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3502632842_791dd4be18_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/5635348214_a4e2b19ffe.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3511104954_54eace015c_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4550117239_5907aaba4c.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/467770225_e3b41d4dd3_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4522153453_06437ca3af_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/5603625247_e4ff1828af_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/5524946579_307dc74476.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/2432389721_4d14971060_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4571353297_5634177744_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4588904196_3c5825c7f4.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4612075317_91eefff68c_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/574373182_2776669a79_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/5628970369_54eb9ed31c_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4573822295_5c5c6a5f6a.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/518256494_368a72db37.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/142235237_da662d925c.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/5546723510_39a5a10d3a_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/11746367_d23a35b085_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/5543457754_89c44c88de_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/471298577_cc7558bcf1.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/2256230386_08b54ca760.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/3186520634_30e1c67aa5_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/4516198427_0e5099cd8e.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/122450705_9885fff3c4_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/tulips/2351637471_5dd34fd3ac_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_ ...
# processing  tulips
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# processing...
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/*.jpg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/*.jpeg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/*.JPG
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/*.JPEG
# ['/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/130733200_fbe28eea19.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2535727910_769c020c0d_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3580437733_9ef51f2981_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3383422012_6c9d83671f_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2625836599_03e192266f.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2553703483_558d12668c_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/10919961_0af657c4e8.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3761310831_41b5eba622_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2330339852_fbbdeb7306_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2444241718_3ca53ce921.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2489438981_4eb60ef98f_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2697283969_c1f9cbb936.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/136999986_e410a68efb_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2472641499_cbe617a93d.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/458011386_ec89115a19.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/1297972485_33266a18d9.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/1273326361_b90ea56d0d_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3451637528_b245144675_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2995221296_a6ddaccc39.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3612582808_4503fa1f8b_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/493696003_f93ffb3abd_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/459633569_5ddf6bc116_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2512148749_261fa9d156.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3505026222_c760df0035_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3465599902_14729e2b1b_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2480853696_aacdbb5324.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/98992760_53ed1d26a9.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/145173479_7d04346c20.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/4489359360_09db62f825.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/16159487_3a6615a565_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3021333497_b927cd8596.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2634666217_d5ef87c9f7_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3149809654_6a4b31314d_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3998927705_af499a4f29.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2443192475_c64c66d9c2.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/2517777524_e871ec5291_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3509307596_6cfe97867d_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/8475769_3dea463364_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/1195255751_d58b3d3076.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/3446018470_0c40e73ed6_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/dandelion/4275776457_d04b597cfa_n.jpg', '/home/se7ven/Desktop/ResNet-V1- ...
# processing  dandelion
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# processing...
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/*.jpg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/*.jpeg
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/*.JPG
# /home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/*.JPEG
# ['/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3734999477_7f454081aa_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3950020811_dab89bebc0_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/2803725948_5fd1f2fc99_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4933229197_ff75a40d55.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3912497888_e7a5905bc3_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/5043409092_5b12cc985a_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4528959364_fa544b0f4e_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3683873444_be4a609c46.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4846786944_2832c5c8b8.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/1240626292_52cd5d7fb1_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4940287066_385afd9c18_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3840761441_7c648abf4d_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4933230991_d50c0f7c66.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3311874685_7b9ef10f7e_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/1596293240_2d5b53495a_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4942258704_c4146b710a_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/5025805406_033cb03475_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/5139971615_434ff8ed8b_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/857698097_8068a2c135_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/40410814_fba3837226_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3146795631_d062f233c1.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/5037531593_e2daf4c7f1.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3784815653_5df39aa9c2_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3001536784_3bfd101b23_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/40411019_526f3fc8d9_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4895122831_83db2ba2d0_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3846717708_ea11383ed8.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4235259239_21f2eb4f2e.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/877083343_e3338c4125.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/2729206569_9dd2b5a3ed.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3665455426_9cd1c3af4a_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/1064662314_c5a7891b9f_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/4341530649_c17bbc5d01.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/40410686_272bc66faf_m.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/164672339_f2b5b164f6.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/40411100_7fbe10ec0f_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/2960610406_b61930727f_n.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/2721638730_34a9b7a78b.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/1244774242_25a20d99a9.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/3858508462_db2b9692d1.jpg', '/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_photos/sunflowers/175638423_0 ...
# processing  sunflowers
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# processing...
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)
# (300, 300, 3)

# %%
import numpy as np
import tensorflow as tf
import tensorflow.contrib.slim as slim
# 加载通过slim定义好的resnet_v1模型
import tensorflow.contrib.slim.python.slim.nets.resnet_v1 as resnet_v1

# 数据文件
INPUT_DATA = "/home/se7ven/Desktop/ResNet-V1-50/datasets/flower_processed_data.npy"
# 保存训练好的模型
TRAIN_FILE = "train_dir/model"
# 提供的已经训练好的模型
CKPT_FILE = "/home/se7ven/Desktop/ResNet-V1-50/datasets/resnet_v1_50.ckpt"

# 定义训练所用参数
LEARNING_RATE = 0.0001
STEPS = 500
BATCH = 32
N_CLASSES = 5

# 这里指出了不需要从训练好的模型中加载的参数，就是最后的自定义的全连接层
CHECKPOINT_EXCLUDE_SCOPES = 'Logits'
# 指定最后的全连接层为可训练的参数
TRAINABLE_SCOPES = 'Logits'


# 加载所有需要从训练好的模型加载的参数
def get_tuned_variables():
    ##不需要加载的范围
    exclusions = [scope.strip() for scope in CHECKPOINT_EXCLUDE_SCOPES.split(",")]
    # 初始化需要加载的参数
    variables_to_restore = []

    # 遍历模型中的所有参数
    for var in slim.get_model_variables():
        # 先指定为不需要移除
        excluded = False
        # 遍历exclusions，如果在exclusions中，就指定为需要移除
        for exclusion in exclusions:
            if var.op.name.startswith(exclusion):
                excluded = True
                break
        # 如果遍历完后还是不需要移除，就把参数加到列表里
        if not excluded:
            variables_to_restore.append(var)
    return variables_to_restore


# 获取所有需要训练的参数
def get_trainable_variables():
    # 同上
    scopes = [scope.strip() for scope in TRAINABLE_SCOPES.split(",")]
    variables_to_train = []
    # 枚举所有需要训练的参数的前缀，并找到这些前缀的所有参数
    for scope in scopes:
        variables = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope)
        variables_to_train.extend(variables)
    return variables_to_train


def main():
    
    # 这里是因为numpy的版本更新了 如果不allow_pickle=True会报错，于是先打开，再改回来
    np_load_old = np.load
    # modify the default parameters of np.load
    np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
    
    # 加载数据
    processed_data = np.load(INPUT_DATA)
    
    # restore np.load for future normal usage
    np.load = np_load_old
    
    training_images = processed_data[0]
    n_training_example = len(training_images)
    training_labels = processed_data[1]
    validation_images = processed_data[2]
    validation_labels = processed_data[3]
    testing_images = processed_data[4]
    testing_labels = processed_data[5]

    print("there is %d training examples, %d validation examples, %d testing examples" %
          (n_training_example, len(validation_labels), len(testing_labels)))

    # 定义数据格式
    images = tf.placeholder(tf.float32, [None, 300, 300, 3], name='input_images')
    labels = tf.placeholder(tf.int64, [None], name='labels')

    # 定义模型，因为给出的只有参数，并没有模型，这里需要指定模型的具体结构
    with slim.arg_scope(resnet_v1.resnet_arg_scope()):
        # logits就是最后预测值，images就是输入数据，指定num_classes=None是为了使resnet模型最后的输出层禁用
        logits, _ = resnet_v1.resnet_v1_50(images, num_classes=None)

    #自定义的输出层
    with tf.variable_scope("Logits"):
        #将原始模型的输出数据去掉维度为2和3的维度，最后只剩维度1的batch数和维度4的300*300*3
        #也就是将原来的二三四维度全部压缩到第四维度
        net = tf.squeeze(logits, axis=[1,2])
        #加入一层dropout层
        net = slim.dropout(net, keep_prob=0.5,scope='dropout_scope')
        #加入一层全连接层，指定最后输出大小
        logits = slim.fully_connected(net, num_outputs=N_CLASSES, scope='fc')


    # 获取需要训练的变量
    trainable_variables = get_trainable_variables()

    # 定义损失，模型定义的时候已经考虑了正则化了
    tf.losses.softmax_cross_entropy(tf.one_hot(labels, N_CLASSES), logits, weights=1.0)
    # 定义训练过程
    train_step = tf.train.RMSPropOptimizer(LEARNING_RATE).minimize(tf.losses.get_total_loss())

    # 定义测试和验证过程
    with tf.name_scope('evaluation'):
        correct_prediction = tf.equal(tf.argmax(logits, 1), labels)
        evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    # 定义加载模型的函数，就是重新定义load_fn函数，从文件中获取参数，获取指定的变量，忽略缺省值
    load_fn = slim.assign_from_checkpoint_fn(CKPT_FILE, get_tuned_variables(), ignore_missing_vars=True)

    # 定义保存新的训练好的模型的函数
    saver = tf.train.Saver()
    with tf.Session() as sess:
        # 初始化没有加载进来的变量，一定要在模型加载之前，否则会将训练好的参数重新赋值
        init = tf.global_variables_initializer()
        sess.run(init)

        # 加载训练好的模型
        print('Loading tuned variables from %s' % CKPT_FILE)
        load_fn(sess)

        start = 0
        end = BATCH
        for i in range(STEPS):
            # 训练...
            sess.run(train_step, feed_dict={images: training_images[start:end],
                                            labels: training_labels[start:end]})
            # 间断地保存模型，并在验证集上验证
            if i % 50 == 0 or i + 1 == STEPS:
                saver.save(sess, TRAIN_FILE, global_step=i)
                validation_accuracy = sess.run(evaluation_step, feed_dict={images: validation_images,
                                                                           labels: validation_labels})
                print('Step %d: Validation accuracy = %.1f%%' % (
                    i, validation_accuracy * 100.0))

            # 更新起始和末尾,获取下一个batch
            start = end
            if start == n_training_example:
                start = 0
            end = start + BATCH
            if end > n_training_example:
                end = n_training_example

        # 训练完了在测试集上测试正确率
        testing_accuracy = sess.run(evaluation_step, feed_dict={images: testing_images,
                                                                labels: testing_labels})
        print('Final test accuracy = %.1f%%' % (testing_accuracy * 100))


if __name__ == '__main__':
    main()
# Out:
# there is 1215 training examples, 144 validation examples, 141 testing examples
# WARNING: Logging before flag parsing goes to stderr.
# W0829 23:02:37.941703 140606184159040 deprecation.py:323] From /home/se7ven/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0829 23:02:39.068042 140606184159040 deprecation.py:506] From /home/se7ven/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0829 23:02:43.354056 140606184159040 deprecation.py:323] From /home/se7ven/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading tuned variables from /home/se7ven/Desktop/ResNet-V1-50/datasets/resnet_v1_50.ckpt
# Step 0: Validation accuracy = 20.8%
# Step 50: Validation accuracy = 27.1%
# Step 100: Validation accuracy = 72.9%
# Step 150: Validation accuracy = 91.7%
# Step 200: Validation accuracy = 95.1%
# W0829 23:04:58.831627 140606184159040 deprecation.py:323] From /home/se7ven/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Step 250: Validation accuracy = 95.1%
# Step 300: Validation accuracy = 93.1%
# Step 350: Validation accuracy = 93.1%
# Step 400: Validation accuracy = 91.0%
# Step 450: Validation accuracy = 93.8%
# Step 499: Validation accuracy = 91.7%
# Final test accuracy = 92.9%
